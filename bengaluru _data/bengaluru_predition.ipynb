# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Bengaluru_House_Data.csv')
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df = df.drop(columns=['availability'])

# %%
df['location'].value_counts()
# Out:
# location
# Whitefield                        540
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: count, Length: 1305, dtype: int64

# %%
df['location']= df['location'].fillna(df['location'].mode()[0])

# %%
df['location'].isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area_type   13320 non-null  object
#  1   location    13320 non-null  object
#  2   size        13304 non-null  object
#  3   society     7818 non-null   object
#  4   total_sqft  13320 non-null  object
#  5   bath        13247 non-null  float64
#  6   balcony     12711 non-null  float64
#  7   price       13320 non-null  float64
# dtypes: float64(3), object(5)
# memory usage: 832.6+ KB

# %%
df.isnull().sum()
# Out:
# area_type        0
# location         0
# size            16
# society       5502
# total_sqft       0
# bath            73
# balcony        609
# price            0
# dtype: int64

# %%
df['size'].value_counts()
# Out:
# size
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 BHK           2
# 11 Bedroom       2
# 10 BHK           2
# 14 BHK           1
# 13 BHK           1
# 12 Bedroom       1
# 27 BHK           1
# 43 Bedroom       1
# 16 BHK           1
# 19 BHK           1
# 18 Bedroom       1
# Name: count, dtype: int64

# %%
df['size'] = df['size'].astype('str')

# %%
df['BHK'] = df['size'].apply(lambda x:1 if 'BHK' in x else 0)

# %%
df.head()
# Out:
#               area_type                  location       size  society  \
# 0  Super built-up  Area  Electronic City Phase II      2 BHK  Coomee
# 1            Plot  Area          Chikka Tirupathi  4 Bedroom  Theanmp
# 2        Built-up  Area               Uttarahalli      3 BHK      NaN
# 3  Super built-up  Area        Lingadheeranahalli      3 BHK  Soiewre
# 4  Super built-up  Area                  Kothanur      2 BHK      NaN
#
#   total_sqft  bath  balcony   price  BHK
# 0       1056   2.0      1.0   39.07    1
# 1       2600   5.0      3.0  120.00    0
# 2       1440   2.0      3.0   62.00    1
# 3       1521   3.0      1.0   95.00    1
# 4       1200   2.0      1.0   51.00    1

# %%
df = df[df['size'] != 'nan'].dropna()

# %%
df.isnull().sum()
# Out:
# area_type     0
# location      0
# size          0
# society       0
# total_sqft    0
# bath          0
# balcony       0
# price         0
# BHK           0
# dtype: int64

# %%
df['size'].value_counts()
# Out:
# size
# 2 BHK        3411
# 3 BHK        3013
# 1 BHK         353
# 4 BHK         347
# 4 Bedroom     193
# 3 Bedroom     120
# 5 Bedroom      16
# 2 Bedroom      16
# 1 RK           10
# 5 BHK           9
# 6 BHK           3
# 6 Bedroom       3
# 11 BHK          1
# 9 BHK           1
# 7 BHK           1
# Name: count, dtype: int64

# %%
df['House']=df['size'].str.split(' ').str.get(0)

# %%
df.head()
# Out:
#                area_type                  location       size  society  \
# 0   Super built-up  Area  Electronic City Phase II      2 BHK  Coomee
# 1             Plot  Area          Chikka Tirupathi  4 Bedroom  Theanmp
# 3   Super built-up  Area        Lingadheeranahalli      3 BHK  Soiewre
# 5   Super built-up  Area                Whitefield      2 BHK  DuenaTa
# 11            Plot  Area                Whitefield  4 Bedroom  Prrry M
#
#    total_sqft  bath  balcony   price  BHK House
# 0        1056   2.0      1.0   39.07    1     2
# 1        2600   5.0      3.0  120.00    0     4
# 3        1521   3.0      1.0   95.00    1     3
# 5        1170   2.0      1.0   38.00    1     2
# 11       2785   5.0      3.0  295.00    0     4

# %%
df['total_sqft'].isnull().sum()
# Out:
# 0

# %%
df['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1521', ..., '1919', '2111', '4689'], dtype=object)

# %%
df = df.drop(columns=['area_type','society','balcony'])

# %%
df.head()
# Out:
#                     location       size total_sqft  bath   price  BHK House
# 0   Electronic City Phase II      2 BHK       1056   2.0   39.07    1     2
# 1           Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    0     4
# 3         Lingadheeranahalli      3 BHK       1521   3.0   95.00    1     3
# 5                 Whitefield      2 BHK       1170   2.0   38.00    1     2
# 11                Whitefield  4 Bedroom       2785   5.0  295.00    0     4

# %%
df['total_sqft'].value_counts()
# Out:
# total_sqft
# 1200           172
# 1100           106
# 1000            78
# 1500            74
# 1300            71
#               ...
# 2383             1
# 1103             1
# 1145 - 1340      1
# 3080             1
# 4689             1
# Name: count, Length: 1682, dtype: int64

# %%
def conv(x):
    if 'Yards' in x:
        x = x.split(' ')
        x[0] = float(x[0].replace('Sq.',''))
        val = int(x[0]*9)
        return val
    elif 'Meter' in x:
        x = x.split(' ')
        x[0] = float(x[0].replace('Sq.',''))
        val = int(x[0]*10.7639)
        return val
    elif ' - ' in x:
        x = x.split('-')
        c = (float(x[0])+float(x[1]))/2
        return int(c)
    else:
        return x

# %%
total = df['total_sqft'].apply(conv)
total
# Out:
# 0        1056
# 1        2600
# 3        1521
# 5        1170
# 11       2785
#          ...
# 13313    1345
# 13314    1715
# 13315    3453
# 13317    1141
# 13318    4689
# Name: total_sqft, Length: 7497, dtype: object

# %%
total.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 7497 entries, 0 to 13318
# Series name: total_sqft
# Non-Null Count  Dtype
# --------------  -----
# 7497 non-null   object
# dtypes: object(1)
# memory usage: 117.1+ KB

# %%
total.isnull().sum()
# Out:
# 0

# %%
def flt(x):
    if is_float(x) == True:
        x = round(float(x),0)
        return int(x)
    else:
        return x
def is_float(string):
    try:
        float(string)
        return True
    except ValueError:
        return False

# %%
total = total.apply(flt)
total
# Out:
# 0        1056
# 1        2600
# 3        1521
# 5        1170
# 11       2785
#          ...
# 13313    1345
# 13314    1715
# 13315    3453
# 13317    1141
# 13318    4689
# Name: total_sqft, Length: 7497, dtype: object

# %%
total[total.str.isnumeric() != False].dropna()
# Out:
# 0        1056
# 1        2600
# 3        1521
# 5        1170
# 11       2785
#          ...
# 13313    1345
# 13314    1715
# 13315    3453
# 13317    1141
# 13318    4689
# Name: total_sqft, Length: 7496, dtype: object

# %%
df['total_sqft'] = total

# %%
df.head()
# Out:
#                     location       size total_sqft  bath   price  BHK House
# 0   Electronic City Phase II      2 BHK       1056   2.0   39.07    1     2
# 1           Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    0     4
# 3         Lingadheeranahalli      3 BHK       1521   3.0   95.00    1     3
# 5                 Whitefield      2 BHK       1170   2.0   38.00    1     2
# 11                Whitefield  4 Bedroom       2785   5.0  295.00    0     4

# %%
df = df[df['total_sqft'].str.isnumeric() != False].dropna()
df.head()
# Out:
#                     location       size total_sqft  bath   price  BHK House
# 0   Electronic City Phase II      2 BHK       1056   2.0   39.07    1     2
# 1           Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    0     4
# 3         Lingadheeranahalli      3 BHK       1521   3.0   95.00    1     3
# 5                 Whitefield      2 BHK       1170   2.0   38.00    1     2
# 11                Whitefield  4 Bedroom       2785   5.0  295.00    0     4

# %%
df.shape
# Out:
# (7496, 7)

# %%
df.head()
# Out:
#                     location       size total_sqft  bath   price  BHK House
# 0   Electronic City Phase II      2 BHK       1056   2.0   39.07    1     2
# 1           Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    0     4
# 3         Lingadheeranahalli      3 BHK       1521   3.0   95.00    1     3
# 5                 Whitefield      2 BHK       1170   2.0   38.00    1     2
# 11                Whitefield  4 Bedroom       2785   5.0  295.00    0     4

# %%
df.describe()
# Out:
#               bath        price          BHK
# count  7496.000000  7496.000000  7496.000000
# mean      2.458378    96.839646     0.952375
# std       0.881128   105.373426     0.212987
# min       1.000000     8.000000     0.000000
# 25%       2.000000    49.500000     1.000000
# 50%       2.000000    69.755000     1.000000
# 75%       3.000000   105.000000     1.000000
# max       9.000000  2700.000000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7496 entries, 0 to 13318
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    7496 non-null   object
#  1   size        7496 non-null   object
#  2   total_sqft  7496 non-null   object
#  3   bath        7496 non-null   float64
#  4   price       7496 non-null   float64
#  5   BHK         7496 non-null   int64
#  6   House       7496 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 468.5+ KB

# %%
df['House'] = df['House'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7496 entries, 0 to 13318
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    7496 non-null   object
#  1   size        7496 non-null   object
#  2   total_sqft  7496 non-null   object
#  3   bath        7496 non-null   float64
#  4   price       7496 non-null   float64
#  5   BHK         7496 non-null   int64
#  6   House       7496 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 468.5+ KB

# %%
x=df[['location','total_sqft','bath','BHK','House']]
y=df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=32)

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import OneHotEncoder 
from sklearn.compose import make_column_transformer 
from sklearn.pipeline import make_pipeline 
from sklearn.metrics import r2_score

# %%
ohe=OneHotEncoder() 
ohe.fit(x[['location','total_sqft']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['location','total_sqft']),remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array([' Banaswadi', ' Bhoganhalli', ' Devarabeesana Halli',
#        ' Devarachikkanahalli', ' Electronic City', ' Rachenahalli',
#        ' Thanisandra', ' Whitefield', '1 Giri Nagar',
#        '1st Block Jayanagar', '1st Block Koramangala',
#        '1st Phase JP Nagar', '2nd Bl...
#        'Vishwapriya Layout', 'Vishwapriya Nagar', 'Vittal Mallya Road',
#        'Vittal Nagar', 'Vittasandra', 'Volagerekallahalli', 'Whitefield',
#        'Wilson Garden', 'Yelachenahalli', 'Yelahanka',
#        'Yelahanka New Town', 'Yelenahalli', 'Yemlur', 'Yeshwanthpur',
#        'Yeshwanthpur Industrial Suburb'], dtype=object),
# ...

# %%
y_pred=pipe.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4354888414026509
